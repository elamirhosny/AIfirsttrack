# %%
import sys
class Library:
      def __init__(user,listofbooks):
            print("Welcome to our library...")
            user.name=input("Enter your name: ")
            user.password=int(input("Enter your password: "))
            print("Your ID is: ", id(user))
            user.availablebooks=listofbooks

      def displayAvailablebooks(user):
                   print("The books we have in our library are as follows:")
                   print("================================")
                   for book in user.availablebooks:
                         print(book)
      def lendBook(user,requestedBook):
                if requestedBook in user.availablebooks:
                      print("The book you requested has now been borrowed")
                      user.availablebooks.remove(requestedBook)
                else:
                      print("Sorry the book you have requested is currently not in the library")
                  
      def addBook(user,returnedBook):
            user.availablebooks.append(returnedBook)
            print("Thanks for returning your borrowed book")
            

class Student:
      def requestBook(user):
            print("Enter the name of the book you'd like to borrow>>")
            user.book=input()
            return user.book

      def returnBook(user):
            print("Enter the name of the book you'd like to return>>")
            user.book=input()
            return user.book

def main():            
      library=Library(["Introductio to python","Fluid Mechanics","CS50","Computer Vision","Linear Algebra"])
      student=Student()
      done=False
      while done==False:
            print(""" ======LIBRARY MENU=======
                  1. Display all available books
                  2. Request a book
                  3. Return a book
                  4. Exit
                  """)
            choice=int(input("Enter Choice:"))
            if choice==1:
                        library.displayAvailablebooks()
            elif choice==2:
                        library.lendBook(student.requestBook())
            elif choice==3:
                        library.addBook(student.returnBook())
            elif choice==4:
                  sys.exit(0)
                  
main()
# Out:
# Welcome to our library...
# Enter your name: amir
# Enter your password: 123
# Your ID is:  1114779192720
#  ======LIBRARY MENU=======
#                   1. Display all available books
#                   2. Request a book
#                   3. Return a book
#                   4. Exit
#
# Enter Choice:1
# The books we have in our library are as follows:
# ...
# Introductio to python
# Fluid Mechanics
# CS50
# Computer Vision
# Linear Algebra
#  ======LIBRARY MENU=======
#                   1. Display all available books
#                   2. Request a book
#                   3. Return a book
#                   4. Exit
#
# Enter Choice:2
# Enter the name of the book you'd like to borrow>>
# Fluid Mechanics
# The book you requested has now been borrowed
#  ======LIBRARY MENU=======
#                   1. Display all available books
#                   2. Request a book
#                   3. Return a book
#                   4. Exit
#
# Enter Choice:1
# ...
